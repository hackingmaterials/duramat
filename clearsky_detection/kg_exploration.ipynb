# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd

# %%
df = pd.read_csv('./Koeppen-Geiger-ASCII.txt', delim_whitespace=True)

# %%
df.head()
# Out:
#      Lat     Lon Cls
# 0 -89.75 -179.75  EF
# 1 -89.75 -179.25  EF
# 2 -89.75 -178.75  EF
# 3 -89.75 -178.25  EF
# 4 -89.75 -177.75  EF

# %%
df.pivot(columns='Lat', index='Lon', values='Cls')
# Out:
# Lat     -89.75 -89.25 -88.75 -88.25 -87.75 -87.25 -86.75 -86.25 -85.75 -85.25  \
# Lon
# -179.75     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -179.25     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -178.75     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -178.25     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -177.75     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -177.25     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -176.75     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -176.25     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -175.75     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -175.25     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# -174.75     EF     EF     EF     EF     EF     EF     EF     EF     EF     EF
# ...

# %%
df2 = df.pivot(columns='Lat', index='Lon', values='Cls')

# %%
df2.loc[-179.75, -89.75]
# Out:
# 'EF'
